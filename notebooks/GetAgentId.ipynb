# %%
#r "nuget:Azure.AI.Projects, 1.2.0-beta.4"
#r "nuget:Azure.AI.Agents.Persistent, 1.1.0"
#r "nuget:Azure.AI.Projects.OpenAI, 1.0.0-beta.4"
#r "nuget:Azure.Identity, 1.17.1"

using Azure.AI.Projects;
using Azure.AI.Projects.OpenAI;
using Azure.Identity;
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.1.0</span></li><li><span>Azure.AI.Projects, 1.2.0-beta.4</span></li><li><span>Azure.AI.Projects.OpenAI, 1.0.0-beta.4</span></li><li><span>Azure.Identity, 1.17.1</span></li></ul></div></div>

# %%
var agentName = "WeatherAgent";
var projectEndpoint = "https://nampacx-fndry-2.services.ai.azure.com/api/projects/nampacx-fndry-prjct";


     var credentialOptions = new DefaultAzureCredentialOptions()
        {
            TenantId = ""
        };

        var credentials = new DefaultAzureCredential(credentialOptions);

var projectClient = new AIProjectClient(endpoint: new Uri(projectEndpoint), tokenProvider: credentials);

  AgentRecord agentRecord = await projectClient.Agents.GetAgentAsync(agentName);
agentRecord.Id
# Out:
# WeatherAgent
